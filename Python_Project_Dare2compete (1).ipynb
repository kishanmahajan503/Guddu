# %%
import warnings
warnings.filterwarnings('ignore')

# Importing Important Libraries for importing csv file and better visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import xticks

# %%
# Read CSV file 
df = pd.read_csv("C:/Users/Kishan Mahajan/Downloads/Data Analysis Challenge Data Set.csv")
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
## To check is their is any null value 
df.isna()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# 5        False              False  False      False       False         False
# 6        False              False  False      False       False         False
# 7        False              False  False      False       False         False
# 8        False              False  False      False       False         False
# 9        False              False  False      False       False         False
# 10       False              False  False      False       False         False
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
## As we can see that their is some value like "?" in col. 2 so we need to replace this value with space , "0" or average value

df['normalized-losses'] = pd.to_numeric(df['normalized-losses'], errors='coerce')
df['bore'] = pd.to_numeric(df['bore'], errors='coerce')
df['stroke'] = pd.to_numeric(df['stroke'], errors='coerce')
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['peak-rpm'] = pd.to_numeric(df['peak-rpm'], errors='coerce')
df['price'] = pd.to_numeric(df['price'], errors='coerce')

df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2                NaN         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1                NaN         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0                NaN         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
df_nonan = df.replace(np.nan, 0)
df_nonan.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                0.0  alfa-romero       gas        std
# 1          3                0.0  alfa-romero       gas        std
# 2          1                0.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df_nonan.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df_nonan.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146          97.600000   98.756585  174.049268   65.907805
# std      1.245307          58.282073    6.021776   12.337289    2.145204
# min     -2.000000           0.000000   86.600000  141.100000   60.300000
# 25%      0.000000          77.000000   94.500000  166.300000   64.100000
# 50%      1.000000         103.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  205.000000  205.000000
# mean    53.724878  2555.565854   126.907317    3.264780    3.191902
# std      2.443522   520.680204    41.642693    0.535268    0.549625
# ...

# %%
cdf = df_nonan[['wheel-base','normalized-losses','highway-mpg','price' , 'stroke' , 'horsepower' , 'engine-size']]

viz = cdf[['wheel-base','normalized-losses','highway-mpg','price' , 'stroke' , 'horsepower' , 'engine-size']]
viz.hist()
plt.show()

# %%
df_numeric=df_nonan.select_dtypes(include=['float64','int64'])
df_numeric.head()
## We need to drop some value as they are more Categorical variable
df_numeric = df_numeric.drop(['symboling'], axis=1)
df_numeric.head()
# Out:
#    normalized-losses  wheel-base  length  width  height  curb-weight  \
# 0                0.0        88.6   168.8   64.1    48.8         2548
# 1                0.0        88.6   168.8   64.1    48.8         2548
# 2                0.0        94.5   171.2   65.5    52.4         2823
# 3              164.0        99.8   176.6   66.2    54.3         2337
# 4              164.0        99.4   176.6   66.4    54.3         2824
#
#    engine-size  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0          130  3.47    2.68                9.0       111.0    5000.0
# 1          130  3.47    2.68                9.0       111.0    5000.0
# 2          152  2.68    3.47                9.0       154.0    5000.0
# 3          109  3.19    3.40               10.0       102.0    5500.0
# 4          136  3.19    3.40                8.0       115.0    5500.0
#
#    city-mpg  highway-mpg    price
# 0        21           27  13495.0
# 1        21           27  16500.0
# ...

# %%
## Check which col has co-relation with each other.
for i, col in enumerate (df_numeric.columns):
    plt.figure(i)
    sns.scatterplot(x=df_numeric[col],y=df_numeric['price'])

# %% [markdown]
# Price is affected by Engine size and horsepower, they both are positively co-related with each other. So we can create a model to predict the price of any vehicle.

# %%
plt.figure(figsize=(10, 20))
plt.subplot(4,2,1)
sns.boxplot(x = 'fuel-type', y = 'price', data = df_nonan)
plt.subplot(4,2,2)
sns.boxplot(x = 'aspiration', y = 'price', data = df_nonan)
plt.subplot(4,2,3)
sns.boxplot(x = 'drive-wheels', y = 'price', data = df_nonan)
plt.subplot(4,2,4)
sns.boxplot(x = 'engine-type', y = 'price', data = df_nonan)
plt.subplot(4,2,5)
sns.boxplot(x = 'num-of-cylinders', y = 'price', data = df_nonan)
plt.tight_layout()
plt.show()

# %%
sns.distplot(df_nonan['price'])

# %%
plt1 = sns.countplot(df_nonan['symboling'])
plt1.set(xlabel = 'Symbol', ylabel= 'Count of Cars')
plt.show()
plt.tight_layout()

# %% [markdown]
# Fuel Type

# %%
df_fuel = df_nonan[['fuel-type','price']].groupby("fuel-type", as_index = False).mean().rename(columns={'price':'fuel_price'})
plt1 = df_fuel.plot(x = 'fuel-type', kind='bar',legend = False, sort_columns = True)
plt1.set_xlabel("Fuel-Type")
plt1.set_ylabel("Avg Price (Dollars)")
xticks(rotation = 0)
plt.show()

# %% [markdown]
# We will create Linear Regression Model

# %%
Linear_Regression = df_nonan[['fuel-type', 'aspiration', 'drive-wheels', 'wheel-base', 'length', 'width', 'curb-weight', 'engine-type',
       'num-of-cylinders', 'engine-size', 'horsepower', 'price', 'highway-mpg']]
Linear_Regression.head()
# Out:
#   fuel-type aspiration drive-wheels  wheel-base  length  width  curb-weight  \
# 0       gas        std          rwd        88.6   168.8   64.1         2548
# 1       gas        std          rwd        88.6   168.8   64.1         2548
# 2       gas        std          rwd        94.5   171.2   65.5         2823
# 3       gas        std          fwd        99.8   176.6   66.2         2337
# 4       gas        std          4wd        99.4   176.6   66.4         2824
#
#   engine-type num-of-cylinders  engine-size  horsepower    price  highway-mpg
# 0        dohc             four          130       111.0  13495.0           27
# 1        dohc             four          130       111.0  16500.0           27
# 2        ohcv              six          152       154.0  16500.0           26
# 3         ohc             four          109       102.0  13950.0           30
# 4         ohc             five          136       115.0  17450.0           22

# %% [markdown]
# Train-Test Split

# %%
from sklearn.model_selection import train_test_split

np.random.seed(0)
df_train, df_test = train_test_split(Linear_Regression, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import LabelEncoder

number = LabelEncoder()
df_train["fuel-type"] = number.fit_transform(df_train["fuel-type"].astype('str'))
df_test["fuel-type"] = number.fit_transform(df_test["fuel-type"].astype('str'))

df_train["drive-wheels"] = number.fit_transform(df_train["drive-wheels"].astype('str'))
df_test["drive-wheels"] = number.fit_transform(df_test["drive-wheels"].astype('str'))

df_train["aspiration"] = number.fit_transform(df_train["aspiration"].astype('str'))
df_test["aspiration"] = number.fit_transform(df_test["aspiration"].astype('str'))

df_train["engine-type"] = number.fit_transform(df_train["engine-type"].astype('str'))
df_test["engine-type"] = number.fit_transform(df_test["engine-type"].astype('str'))

df_train["num-of-cylinders"] = number.fit_transform(df_train["num-of-cylinders"].astype('str'))
df_test["num-of-cylinders"] = number.fit_transform(df_test["num-of-cylinders"].astype('str'))

df_train.head()
# Out:
#      fuel-type  aspiration  drive-wheels  wheel-base    length     width  \
# 122          1           0             1    0.244828  0.426016  0.291667
# 125          1           0             2    0.272414  0.452033  0.666667
# 166          1           0             2    0.272414  0.448780  0.308333
# 1            1           0             2    0.068966  0.450407  0.316667
# 199          1           1             2    0.610345  0.775610  0.575000
#
#      curb-weight  engine-type  num-of-cylinders  engine-size  horsepower  \
# 122     0.272692            3                 2     0.139623    0.236111
# 125     0.500388            3                 2     0.339623    0.496528
# 166     0.314973            0                 2     0.139623    0.388889
# 1       0.411171            0                 2     0.260377    0.385417
# 199     0.647401            3                 2     0.260377    0.562500
#
#         price  highway-mpg
# 122  0.184170     0.567568
# 125  0.532930     0.270270
# ...

# %%
df_train["num-of-cylinders"].value_counts()
# Out:
# 2    106
# 3     19
# 1      9
# 6      4
# 0      3
# 5      1
# 4      1
# Name: num-of-cylinders, dtype: int64

# %%
print(df_train.describe())
print(df_train.dtypes)
# Out:
#         fuel-type  aspiration  drive-wheels  wheel-base      length  \
# count  143.000000  143.000000    143.000000  143.000000  143.000000
# mean     0.909091    0.181818      1.293706    0.411141    0.525476
# std      0.288490    0.387050      0.567080    0.205581    0.204848
# min      0.000000    0.000000      0.000000    0.000000    0.000000
# 25%      1.000000    0.000000      1.000000    0.272414    0.399187
# 50%      1.000000    0.000000      1.000000    0.341379    0.502439
# 75%      1.000000    0.000000      2.000000    0.503448    0.669919
# max      1.000000    1.000000      2.000000    1.000000    1.000000
#
#             width  curb-weight  engine-type  num-of-cylinders  engine-size  \
# count  143.000000   143.000000   143.000000        143.000000   143.000000
# mean     0.461655     0.407878     3.006993          2.174825     0.241351
# std      0.184517     0.211269     1.147542          0.890598     0.154619
# ...

# %%
y_train = df_train.pop('price')
X_train = df_train
